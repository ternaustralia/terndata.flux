# %%
# This shall install tern-data-package onto your jupyter notebook instance.
# !pip install terndata.flux
# Out:
# Collecting git+https://github.com/ternaustralia/terndata.flux
#   Cloning https://github.com/ternaustralia/terndata.flux to /private/var/folders/jj/fc3n4vcj4kv7kzx8n43b4s_w0000gr/T/pip-req-build-mb1bsv4w
#   Running command git clone --filter=blob:none --quiet https://github.com/ternaustralia/terndata.flux /private/var/folders/jj/fc3n4vcj4kv7kzx8n43b4s_w0000gr/T/pip-req-build-mb1bsv4w
#   Resolved https://github.com/ternaustralia/terndata.flux to commit ca6d6fbab0d8cb17a9b56d0ca3f475d34b83e77c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: xarray in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2025.4.0)
# Requirement already satisfied: numpy in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2.2.6)
# Requirement already satisfied: pandas in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2.3.0)
# Requirement already satisfied: geopandas in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (1.1.0)
# Requirement already satisfied: netCDF4 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (1.7.2)
# Requirement already satisfied: requests in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2.32.3)
# Requirement already satisfied: python-dateutil in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2.9.0.post0)
# Requirement already satisfied: pytz in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2025.2)
# Requirement already satisfied: xlrd in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (2.0.1)
# Requirement already satisfied: xlsxwriter in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (3.2.3)
# Requirement already satisfied: defusedxml in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (0.7.1)
# Requirement already satisfied: matplotlib in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from terndata.flux==0.1.dev7+gca6d6fb) (3.10.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from geopandas->terndata.flux==0.1.dev7+gca6d6fb) (0.11.0)
# Requirement already satisfied: packaging in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from geopandas->terndata.flux==0.1.dev7+gca6d6fb) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from geopandas->terndata.flux==0.1.dev7+gca6d6fb) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from geopandas->terndata.flux==0.1.dev7+gca6d6fb) (2.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from pandas->terndata.flux==0.1.dev7+gca6d6fb) (2025.2)
# Requirement already satisfied: certifi in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas->terndata.flux==0.1.dev7+gca6d6fb) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from python-dateutil->terndata.flux==0.1.dev7+gca6d6fb) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from matplotlib->terndata.flux==0.1.dev7+gca6d6fb) (3.2.3)
# Requirement already satisfied: cftime in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from netCDF4->terndata.flux==0.1.dev7+gca6d6fb) (1.6.4.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from requests->terndata.flux==0.1.dev7+gca6d6fb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from requests->terndata.flux==0.1.dev7+gca6d6fb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/uqyliaw/.virtualenvs/jupyterlab/lib/python3.13/site-packages (from requests->terndata.flux==0.1.dev7+gca6d6fb) (2.4.0)

# %%
# Import flux api
from terndata import flux

# %%
# Get sites and their locations available. This take quite a while as it needs to load the dataset for each site to get the locations.
# outout is a geopandas.GeoDataFrame
sites = flux.get_sites()
sites
# Out:
#                                  site   longitude   latitude  \
# 0                       AdelaideRiver  131.117800 -13.076900
# 1                   AliceSpringsMulga  133.249000 -22.283000
# 2                      AlpinePeatland  147.320833 -36.862222
# 3                             Boyagin  116.938559 -32.477093
# 4                    CalperumChowilla  140.587700 -34.002700
# 5                     CapeTribulation  145.446922 -16.103219
# 6                              Collie  116.237000 -33.420000
# 7                              CowBay  145.427150 -16.238189
# 8                     CumberlandPlain  150.723611 -33.615278
# 9                         DalyPasture  131.318100 -14.063300
# 10                      DalyUncleared  131.388100 -14.159200
# 11                    DigbyPlantation  141.616472 -37.882694
# 12                           DryRiver  132.370600 -15.258800
# 13                            Emerald  148.474600 -23.858720
# 14                       Fletcherview  146.189138 -19.887285
# 15                            FoggDam  131.307200 -12.545200
# 16                       GatumPasture  141.960897 -37.390033
# 17                             Gingin  115.713770 -31.376351
# 18              GreatWesternWoodlands  120.654167 -30.191400
# 19                      HowardSprings  131.150050 -12.495200
# 20                         Litchfield  130.794546 -13.179042
# 21    LongreachMitchellGrassRangeland  144.310416 -23.523266
# 22                             Loxton  140.655120 -34.470350
# 23                         MyallValeA  150.020000 -30.543000
# 24                         MyallValeB  150.090000 -30.697000
# 25                              Otway  142.810000 -38.525000
# 26                   RedDirtMelonFarm  132.477567 -14.563639
# 27                         Ridgefield  116.966827 -32.506102
# 28                         RiggsCreek  145.576000 -36.656000
# 29                        RobsonCreek  145.630137 -17.117469
# 30  SamfordEcologicalResearchFacility  152.877780 -27.388060
# 31                       SilverPlains  147.087500 -42.090556
# 32                            SnowGum  148.435850 -36.375649
# 33                        SturtPlains  133.350200 -17.150700
# 34                         TiTreeEast  133.249000 -22.283000
# 35                         Tumbarumba  148.151600 -35.656600
# 36                       WallabyCreek  145.187800 -37.425900
# 37                              Warra  146.654520 -43.095020
# 38                         Wellington  148.984300 -32.572700
# 39                              Whroo  145.029400 -36.673200
# 40                  WombatStateForest  144.094046 -37.422506
# 41                              Yanco  146.290800 -34.987800
# 42                  YarramundiControl  150.734864 -33.613469
# 43                YarramundiIrrigated  150.763284 -33.620812
#
#                                            vegetation  \
# 0                                       Woody Savanna
# 1   Canopy + three types of understorey (vegetatio...
# 2
# 3                           Dry schlerophyll woodland
# 4                                              Mallee
# 5               lowland complex mesophyll vine forest
# 6                           Dry schlerophyll woodland
# 7               lowland complex mesophyll vine forest
# 8                              Dry sclerophyll forest
# 9                           Tropical improved pasture
# 10                                      Woody Savanna
# 11                     Eucalyptus globulus (blue gum)
# 12                                   Woodland savanna
# 13                                    Mallee and crop
# 14                                  Semi-arid savanna
# 15                         Ephemeral tropical wetland
# 16                   Phalaris and Subterranean Clover
# 17                                   Banksia woodland
# 18                           sparse eucalypt woodland
# 19                                      Woody savanna
# 20                                      Woody savanna
# 21                                     Mitchell Grass
# 22                                     Almond orchard
# 23
# 24
# 25                                    Pasture, grazed
# 26                        Woody savannah then cleared
# 27                                              Wheat
# 28                                            Pasture
# 29  Regional Ecosystem (RE) 7.3.36a, complex mesop...
# 30                                            pasture
# 31          Species rich highland grassland/sedgeland
# 32                                Sub-alpine woodland
# 33                                Mitchell Grasslands
# 34  Canopy + three types of understorey (vegetatio...
# 35                             wet sclerophyll forest
# 36                                       Mountain Ash
# 37                     Eucalyptus obliqua tall forest
# 38                                            Pasture
# 39                          Dry schlerophyll woodland
# 40                    dry sclerophyll eucalypt forest
# 41                                            Pasture
# 42                               pasture, unirrigated
# 43                                 pasture, irrigated
#
#                  canopy height                start                  end  \
# 0                        16.4m  2007-10-17 11:30:00  2009-05-24 06:00:00
# 1                         6.5m  2010-09-03 00:00:00  2025-01-28 10:00:00
# 2                         0.3m  2017-04-12 18:30:00  2022-06-20 23:30:00
# 3                        13.0m  2017-10-20 13:00:00  2025-02-02 00:00:00
# 4                           3m  2010-07-30 11:00:00  2025-02-02 00:00:00
# 5                          25m  2010-01-01 00:00:00  2018-11-02 12:00:00
# 6                        12.0m  2017-08-04 00:30:00  2019-11-11 13:30:00
# 7                          26m  2009-01-01 09:00:00  2025-02-02 00:00:00
# 8                         24 m  2014-01-01 00:30:00  2025-01-01 00:00:00
# 9                         0.5m  2008-01-01 00:00:00  2013-09-08 13:30:00
# 10                       16.4m  2008-01-01 00:00:00  2025-02-02 00:00:00
# 11                         +6m  2018-01-01 00:30:00  2021-07-07 12:00:00
# 12                       0.15m  2009-10-25 15:00:00  2025-02-02 00:00:00
# 13                    0.2-0.6m  2011-06-10 00:30:00  2013-12-31 23:30:00
# 14                         12m  2022-01-22 22:00:00  2025-01-17 00:00:00
# 15                        0.5m  2006-02-07 00:00:00  2008-10-31 17:30:00
# 16                       0.05m  2015-02-09 00:30:00  2021-12-31 23:30:00
# 17                        6.8m  2011-10-13 14:00:00  2024-12-31 23:30:00
# 18                          18  2013-01-01 15:30:00  2024-12-31 23:30:00
# 19                         16m  2002-01-01 06:00:00  2025-02-02 00:00:00
# 20                         16m  2015-06-23 13:00:00  2025-01-17 00:00:00
# 21                       0.50m  2018-10-09 12:00:00  2024-07-01 00:00:00
# 22  5.5m (Stevens et al. 2012)  2008-08-19 17:00:00  2009-06-09 10:30:00
# 23                        0.5m  2023-11-29 10:00:00  2025-01-17 00:00:00
# 24                        0.5m  2023-11-28 13:30:00  2025-01-17 00:00:00
# 25                       0.1 m  2007-08-11 00:00:00  2011-01-01 00:00:00
# 26                    variable  2011-09-23 09:00:00  2013-07-21 23:30:00
# 27                          1m  2015-03-29 05:00:00  2025-02-02 00:00:00
# 28                        0.4m  2011-01-01 00:30:00  2017-07-12 17:30:00
# 29                         28m  2013-08-01 17:30:00  2025-02-02 00:00:00
# 30                        0.5m  2010-06-02 12:00:00  2017-12-31 14:30:00
# 31                        0.1m  2019-12-05 10:00:00  2024-12-31 23:30:00
# 32                          8m  2023-12-27 15:30:00  2025-01-17 00:00:00
# 33                        0.5m  2008-08-28 11:00:00  2025-02-02 00:00:00
# 34                        6.5m  2012-07-18 00:00:00  2022-01-17 23:30:00
# 35                        40 m  2002-01-07 16:00:00  2022-12-03 18:00:00
# 36                        100m  2005-08-25 12:30:00  2008-12-31 23:30:00
# 37                         55m  2013-03-05 15:00:00  2021-09-21 12:00:00
# 38                        0.5m  2023-09-27 12:30:00  2025-01-17 00:00:00
# 39                       28.0m  2011-12-01 13:30:00  2023-12-31 23:30:00
# 40                        23 m  2024-05-08 14:30:00  2025-02-02 00:00:00
# 41                        0.50  2012-10-24 14:00:00  2025-01-28 03:00:00
# 42                       0.5 m  2019-10-22 15:30:00  2025-01-01 00:00:00
# 43                       0.5 m  2019-10-15 09:30:00  2024-12-29 12:00:00
#
#                        geometry
# 0     POINT (131.1178 -13.0769)
# 1       POINT (133.249 -22.283)
# 2   POINT (147.32083 -36.86222)
# 3   POINT (116.93856 -32.47709)
# 4     POINT (140.5877 -34.0027)
# 5   POINT (145.44692 -16.10322)
# 6        POINT (116.237 -33.42)
# 7   POINT (145.42715 -16.23819)
# 8   POINT (150.72361 -33.61528)
# 9     POINT (131.3181 -14.0633)
# 10    POINT (131.3881 -14.1592)
# 11  POINT (141.61647 -37.88269)
# 12    POINT (132.3706 -15.2588)
# 13   POINT (148.4746 -23.85872)
# 14  POINT (146.18914 -19.88728)
# 15    POINT (131.3072 -12.5452)
# 16   POINT (141.9609 -37.39003)
# 17  POINT (115.71377 -31.37635)
# 18   POINT (120.65417 -30.1914)
# 19   POINT (131.15005 -12.4952)
# 20  POINT (130.79455 -13.17904)
# 21  POINT (144.31042 -23.52327)
# 22  POINT (140.65512 -34.47035)
# 23       POINT (150.02 -30.543)
# 24       POINT (150.09 -30.697)
# 25       POINT (142.81 -38.525)
# 26  POINT (132.47757 -14.56364)
# 27   POINT (116.96683 -32.5061)
# 28      POINT (145.576 -36.656)
# 29  POINT (145.63014 -17.11747)
# 30  POINT (152.87778 -27.38806)
# 31   POINT (147.0875 -42.09056)
# 32  POINT (148.43585 -36.37565)
# 33    POINT (133.3502 -17.1507)
# 34      POINT (133.249 -22.283)
# 35    POINT (148.1516 -35.6566)
# 36    POINT (145.1878 -37.4259)
# 37  POINT (146.65452 -43.09502)
# 38    POINT (148.9843 -32.5727)
# 39    POINT (145.0294 -36.6732)
# 40  POINT (144.09405 -37.42251)
# 41    POINT (146.2908 -34.9878)
# 42  POINT (150.73486 -33.61347)
# 43  POINT (150.76328 -33.62081)

# %%
# plot sites
sites.plot()
# Out:
# <Axes: >

# %%
# List the dataset versions available for a site
versions = flux.get_versions("AdelaideRiver")
versions
# Out:
# ['2020',
#  '2021_v1',
#  '2022_v1',
#  '2022_v2',
#  '2023_v1',
#  '2023_v2',
#  '2024_v1',
#  '2024_v2']

# %%
# Get processing-levels of a dataset for a specified site and version
levels = flux.get_processing_levels("AdelaideRiver", "2024_v2")
levels
# Out:
# ['L3', 'L4', 'L5', 'L6']

# %%
# Get global attributes for 30min dataset from a site
global_attributes = flux.get_global_attributes("AdelaideRiver")
global_attributes
# Out:
# {'Conventions': 'CF-1.8',
#  'acknowledgement': 'This work used eddy covariance data collected by the TERN Ecosystem \nProcesses facility. Ecosystem Processes would like to acknowledge the financial support of the \nAustralian Federal Government via the National Collaborative Research Infrastructure Scheme \nand the Education Investment Fund.',
#  'canopy_height': '16.4m',
#  'comment': 'CF metadata, OzFlux standard variable names',
#  'contact': 'jason.beringer@uwa.edu.au',
#  'coverage_flux_L3': '86%',
#  'coverage_meteorology_L3': '79%',
#  'coverage_radiation_L3': '94%',
#  'coverage_soil_L3': '94%',
#  'data_link': 'http://data.ozflux.org.au/',
#  'date_created': '2024-08-30 21:26:23',
#  'featureType': 'timeSeries',
#  'fluxnet_id': 'AU-Adr',
#  'history': 'June 2021 processing',
#  'institution': 'University of Western Australia',
#  'latitude': '-13.0769',
#  'license': 'https://creativecommons.org/licenses/by/4.0/',
#  'license_name': 'CC BY 4.0',
#  'longitude': '131.1178',
#  'metadata_link': 'http://www.ozflux.org.au/monitoringsites/AdelaideRiver/index.html',
#  'nc_nrecs': '28070',
#  'ozflux_link': 'http://ozflux.org.au/',
#  'processing_level': 'L3',
#  'publisher_name': 'TERN Ecosystem Processes,OzFlux',
#  'pyfluxpro_version': 'PyFluxPro V3.4.17',
#  'python_version': '3.9.6 | packaged by conda-forge | (default, Jul 11 2021, 03:39:48) \n[GCC 9.3.0]',
#  'references': 'None',
#  'site_name': 'Adelaide River',
#  'site_pi': 'Jason Beringer and Lindsay Hutley',
#  'soil': 'red kandasol',
#  'source': '21m flux tower plus array of soil sensors',
#  'time_coverage_end': '2009-05-24 06:00:00',
#  'time_coverage_start': '2007-10-17 11:30:00',
#  'time_step': '30',
#  'time_zone': 'Australia/Darwin',
#  'title': 'Flux tower data set from the Adelaide River site for the calendar year 2007',
#  'tower_height': '21m',
#  'vegetation': 'Woody Savanna',
#  'DODS.strlen': np.int32(13),
#  'DODS.dimName': 'name_strlen'}

# %%
# Get variables of 30min dataset from a site 
flux.get_variables("AdelaideRiver")
# Out:
# ['time',
#  'latitude',
#  'longitude',
#  'crs',
#  'station_name',
#  'AH',
#  'AH_QCFlag',
#  'AH_HMP_21m',
#  'AH_HMP_21m_QCFlag',
#  'AH_IRGA_Av',
#  'AH_IRGA_Av_QCFlag',
#  'AH_IRGA_Sd',
#  'AH_IRGA_Sd_QCFlag',
#  'AH_IRGA_Vr',
#  'AH_IRGA_Vr_QCFlag',
#  'CO2',
#  'CO2_QCFlag',
#  'CO2_IRGA_Av',
#  'CO2_IRGA_Av_QCFlag',
#  'CO2_IRGA_Sd',
#  'CO2_IRGA_Sd_QCFlag',
#  'CO2_IRGA_Vr',
#  'CO2_IRGA_Vr_QCFlag',
#  'Fa',
#  'Fa_QCFlag',
#  'Fco2',
#  'Fco2_QCFlag',
#  'Fe',
#  'Fe_QCFlag',
#  'Fg',
#  'Fg_QCFlag',
#  'Fg_8cma',
#  'Fg_8cma_QCFlag',
#  'Fg_8cmb',
#  'Fg_8cmb_QCFlag',
#  'Fh',
#  'Fh_QCFlag',
#  'Fld',
#  'Fld_QCFlag',
#  'Flu',
#  'Flu_QCFlag',
#  'Fm',
#  'Fm_QCFlag',
#  'Fn',
#  'Fn_QCFlag',
#  'Fsd',
#  'Fsd_QCFlag',
#  'Fsu',
#  'Fsu_QCFlag',
#  'H2O',
#  'H2O_QCFlag',
#  'L',
#  'L_QCFlag',
#  'Precip',
#  'Precip_QCFlag',
#  'RH',
#  'RH_QCFlag',
#  'SH',
#  'SH_QCFlag',
#  'SHD',
#  'SHD_QCFlag',
#  'Sco2_single',
#  'Sco2_single_QCFlag',
#  'Sws',
#  'Sws_QCFlag',
#  'Sws_5cma',
#  'Sws_5cma_QCFlag',
#  'Sws_5cmb',
#  'Sws_5cmb_QCFlag',
#  'Ta',
#  'Ta_QCFlag',
#  'Ta_HMP_21m',
#  'Ta_HMP_21m_QCFlag',
#  'Ta_SONIC_Av',
#  'Ta_SONIC_Av_QCFlag',
#  'Ts',
#  'Ts_QCFlag',
#  'Ts_8cma',
#  'Ts_8cma_QCFlag',
#  'U_SONIC_Av',
#  'U_SONIC_Av_QCFlag',
#  'U_SONIC_Sd',
#  'U_SONIC_Sd_QCFlag',
#  'U_SONIC_Vr',
#  'U_SONIC_Vr_QCFlag',
#  'VP',
#  'VP_QCFlag',
#  'VPD',
#  'VPD_QCFlag',
#  'V_SONIC_Av',
#  'V_SONIC_Av_QCFlag',
#  'V_SONIC_Sd',
#  'V_SONIC_Sd_QCFlag',
#  'V_SONIC_Vr',
#  'V_SONIC_Vr_QCFlag',
#  'W_SONIC_Av',
#  'W_SONIC_Av_QCFlag',
#  'W_SONIC_Sd',
#  'W_SONIC_Sd_QCFlag',
#  'W_SONIC_Vr',
#  'W_SONIC_Vr_QCFlag',
#  'Wd',
#  'Wd_QCFlag',
#  'Wd_SONIC_Av',
#  'Wd_SONIC_Av_QCFlag',
#  'Ws',
#  'Ws_QCFlag',
#  'Ws_SONIC_Av',
#  'Ws_SONIC_Av_QCFlag',
#  'ps',
#  'ps_QCFlag',
#  'ustar',
#  'ustar_QCFlag']

# %%
# Get 30min dataset variable's attribute
flux.get_attributes("AdelaideRiver", "2024_v2", "L6", ["Wd", "Wd_QCFlag"])
# Out:
# {'Wd': {'coverage_L3': '94%',
#   'coverage_L4': '100%',
#   'coverage_L5': '100%',
#   'coverage_L6': '100%',
#   'description_L4': 'Gap filled using aws, era5, climatology',
#   'height': '21m',
#   'instrument': 'CSAT',
#   'long_name': 'Wind direction',
#   'standard_name': 'wind_from_direction',
#   'statistic_type': 'average',
#   'units': 'degrees',
#   'valid_range': array([  0., 360.])},
#  'Wd_QCFlag': {'long_name': 'WdQC flag', 'units': '1'}}

# %%
# Get 30min dataset variable's attributes, default latest version and L3 processing-level
flux.get_attributes("AdelaideRiver", variables=["AH", "CO2"])
# Out:
# {'AH': {'coverage_L3': '94%',
#   'height': '21m',
#   'instrument': 'HMP45C',
#   'long_name': 'Absolute humidity',
#   'standard_name': 'mass_concentration_of_water_vapor_in_air',
#   'statistic_type': 'average',
#   'units': 'g/m^3',
#   'valid_range': array([ 0., 35.])},
#  'CO2': {'coverage_L3': '87%',
#   'height': '21.0',
#   'instrument': 'Li-7500',
#   'long_name': 'CO2 concentration',
#   'standard_name': 'mole_fraction_of_carbon_dioxide_in_air',
#   'statistic_type': 'average',
#   'units': 'umol/mol',
#   'valid_range': array([250., 900.])}}

# %%
# temporal range for 30min dataset (default)
flux.get_temporal_range("AdelaideRiver", "2024_v2", "L6")
# Out:
# ('2007-10-17T11:30:00.000000000', '2009-05-24T06:00:00.000000000')

# %%
# Get 30min dataset from a site, Output is a Xarray.Dataset
ds = flux.get_dataset("AdelaideRiver", "2024_v2", "L3")
ds
# Out:
# <xarray.Dataset> Size: 18MB
# Dimensions:             (time: 28070, latitude: 1, longitude: 1)
# Coordinates:
#   * time                (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2...
#   * latitude            (latitude) float64 8B -13.08
#   * longitude           (longitude) float64 8B 131.1
# Data variables: (12/110)
#     crs                 int32 4B ...
#     station_name        |S64 64B ...
#     AH                  (time, latitude, longitude) float64 225kB ...
#     AH_QCFlag           (time, latitude, longitude) int32 112kB ...
#     AH_HMP_21m          (time, latitude, longitude) float64 225kB ...
#     AH_HMP_21m_QCFlag   (time, latitude, longitude) int32 112kB ...
#     ...                  ...
#     Ws_SONIC_Av         (time, latitude, longitude) float64 225kB ...
#     Ws_SONIC_Av_QCFlag  (time, latitude, longitude) int32 112kB ...
#     ps                  (time, latitude, longitude) float64 225kB ...
#     ps_QCFlag           (time, latitude, longitude) int32 112kB ...
#     ustar               (time, latitude, longitude) float64 225kB ...
#     ustar_QCFlag        (time, latitude, longitude) int32 112kB ...
# Attributes: (12/40)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     coverage_flux_L3:         86%
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %%
# Get 30min dataset from a site, and set missing value. Output is a Xarray.Dataset
import numpy as np
ds2 = flux.get_dataset("AdelaideRiver", "2024_v2", "L3", missing_as_nan=True)

# print out the variables with na value, and a count of na
for var in list(ds2.variables.keys()):
  if var in list(ds2.coords) + ["crs", "station_name"]:
    continue
  fill_count = int(np.sum((ds[var] == -9999)).values)
  na_count = int(np.sum((np.isnan(ds[var]))).values)
  fill_count2 = int(np.sum((ds2[var] == -9999)).values)
  na_count2 = int(np.sum((np.isnan(ds2[var]))).values)
  if fill_count or na_count:
      print(f"{var}: fill: {fill_count2} ({fill_count}), na: {na_count2} ({na_count})")
# Out:
# AH: fill: 0 (1421), na: 1421 (0)
# AH_HMP_21m: fill: 0 (1418), na: 1418 (0)
# AH_IRGA_Av: fill: 0 (3591), na: 3591 (0)
# AH_IRGA_Sd: fill: 0 (3599), na: 3599 (0)
# AH_IRGA_Vr: fill: 0 (3983), na: 3983 (0)
# CO2: fill: 0 (3604), na: 3604 (0)
# CO2_IRGA_Av: fill: 0 (3604), na: 3604 (0)
# CO2_IRGA_Sd: fill: 0 (3582), na: 3582 (0)
# CO2_IRGA_Vr: fill: 0 (6572), na: 6572 (0)
# Fa: fill: 0 (1490), na: 1490 (0)
# Fco2: fill: 0 (5033), na: 5033 (0)
# Fe: fill: 0 (4382), na: 4382 (0)
# Fg: fill: 0 (1557), na: 1557 (0)
# Fg_8cma: fill: 0 (1477), na: 1477 (0)
# Fg_8cmb: fill: 0 (1468), na: 1468 (0)
# Fh: fill: 0 (4341), na: 4341 (0)
# Fld: fill: 0 (1494), na: 1494 (0)
# Flu: fill: 0 (1494), na: 1494 (0)
# Fm: fill: 0 (2403), na: 2403 (0)
# Fn: fill: 0 (1424), na: 1424 (0)
# Fsd: fill: 0 (1425), na: 1425 (0)
# Fsu: fill: 0 (1425), na: 1425 (0)
# H2O: fill: 0 (1456), na: 1456 (0)
# L: fill: 0 (4405), na: 4405 (0)
# Precip: fill: 0 (28070), na: 28070 (0)
# RH: fill: 0 (1417), na: 1417 (0)
# SH: fill: 0 (1452), na: 1452 (0)
# SHD: fill: 0 (1452), na: 1452 (0)
# Sco2_single: fill: 0 (3977), na: 3977 (0)
# Sws: fill: 0 (1419), na: 1419 (0)
# Sws_5cma: fill: 0 (1419), na: 1419 (0)
# Sws_5cmb: fill: 0 (1419), na: 1419 (0)
# Ta: fill: 0 (1417), na: 1417 (0)
# Ta_HMP_21m: fill: 0 (1425), na: 1425 (0)
# Ta_SONIC_Av: fill: 0 (2104), na: 2104 (0)
# Ts: fill: 0 (1426), na: 1426 (0)
# Ts_8cma: fill: 0 (1426), na: 1426 (0)
# U_SONIC_Av: fill: 0 (2104), na: 2104 (0)
# U_SONIC_Sd: fill: 0 (2246), na: 2246 (0)
# U_SONIC_Vr: fill: 0 (2246), na: 2246 (0)
# VP: fill: 0 (1421), na: 1421 (0)
# VPD: fill: 0 (1421), na: 1421 (0)
# V_SONIC_Av: fill: 0 (2104), na: 2104 (0)
# V_SONIC_Sd: fill: 0 (2246), na: 2246 (0)
# V_SONIC_Vr: fill: 0 (2246), na: 2246 (0)
# W_SONIC_Av: fill: 0 (2104), na: 2104 (0)
# W_SONIC_Sd: fill: 0 (2246), na: 2246 (0)
# W_SONIC_Vr: fill: 0 (2246), na: 2246 (0)
# Wd: fill: 0 (1414), na: 1414 (0)
# Wd_SONIC_Av: fill: 0 (1414), na: 1414 (0)
# Ws: fill: 0 (1494), na: 1494 (0)
# Ws_SONIC_Av: fill: 0 (1494), na: 1494 (0)
# ps: fill: 0 (1451), na: 1451 (0)
# ustar: fill: 0 (2246), na: 2246 (0)

# %%
# Get 30min datasets from 2 sites
datasets = flux.get_datasets(["AdelaideRiver", "Warra"] , "2024_v2", "L6")
datasets
# Out:
# {'AdelaideRiver': <xarray.Dataset> Size: 24MB
#  Dimensions:             (time: 28070, latitude: 1, longitude: 1)
#  Coordinates:
#    * time                (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2...
#    * latitude            (latitude) float64 8B -13.08
#    * longitude           (longitude) float64 8B 131.1
#  Data variables: (12/142)
#      crs                 int32 4B ...
#      station_name        |S64 64B ...
#      AH                  (time, latitude, longitude) float64 225kB ...
#      AH_QCFlag           (time, latitude, longitude) int32 112kB ...
#      AH_HMP_21m          (time, latitude, longitude) float64 225kB ...
#      AH_HMP_21m_QCFlag   (time, latitude, longitude) int32 112kB ...
#      ...                  ...
#      Ws_SONIC_Av         (time, latitude, longitude) float64 225kB ...
#      Ws_SONIC_Av_QCFlag  (time, latitude, longitude) int32 112kB ...
#      ps                  (time, latitude, longitude) float64 225kB ...
#      ps_QCFlag           (time, latitude, longitude) int32 112kB ...
#      ustar               (time, latitude, longitude) float64 225kB ...
#      ustar_QCFlag        (time, latitude, longitude) int32 112kB ...
#  Attributes: (12/53)
#      Conventions:              CF-1.8
#      acknowledgement:          This work used eddy covariance data collected b...
#      canopy_height:            16.4m
#      comment:                  CF metadata, OzFlux standard variable names
#      contact:                  jason.beringer@uwa.edu.au
#      controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#      ...                       ...
#      time_zone:                Australia/Darwin
#      title:                    Flux tower data set from the Adelaide River sit...
#      tower_height:             21m
#      vegetation:               Woody Savanna
#      DODS.strlen:              13
#      DODS.dimName:             name_strlen,
#  'Warra': <xarray.Dataset> Size: 191MB
#  Dimensions:                  (time: 149851, latitude: 1, longitude: 1)
#  Coordinates:
#    * time                     (time) datetime64[ns] 1MB 2013-03-05T15:00:00 .....
#    * latitude                 (latitude) float64 8B -43.1
#    * longitude                (longitude) float64 8B 146.7
#  Data variables: (12/210)
#      crs                      int32 4B ...
#      station_name             |S64 64B ...
#      AH                       (time, latitude, longitude) float64 1MB ...
#      AH_QCFlag                (time, latitude, longitude) int32 599kB ...
#      AH_HMP_80m               (time, latitude, longitude) float64 1MB ...
#      AH_HMP_80m_QCFlag        (time, latitude, longitude) int32 599kB ...
#      ...                       ...
#      Ws_WS4_Av                (time, latitude, longitude) float64 1MB ...
#      Ws_WS4_Av_QCFlag         (time, latitude, longitude) int32 599kB ...
#      ps                       (time, latitude, longitude) float64 1MB ...
#      ps_QCFlag                (time, latitude, longitude) int32 599kB ...
#      ustar                    (time, latitude, longitude) float64 1MB ...
#      ustar_QCFlag             (time, latitude, longitude) int32 599kB ...
#  Attributes: (12/54)
#      Conventions:              CF-1.8
#      acknowledgement:          This work used eddy covariance data collected b...
#      altitude:                 108m
#      canopy_height:            55m
#      comment:                  CF metadata, OzFlux standard variable names
#      contact:                  Tim Wardlaw
#      ...                       ...
#      time_zone:                Australia/Hobart
#      title:                    Flux tower data set from the Warra site for the...
#      tower_height:             80
#      vegetation:               Eucalyptus obliqua tall forest
#      DODS.strlen:              5
#      DODS.dimName:             name_strlen}

# %%
# Get a subset of 30min dataset, slice to 2 variables
subset = flux.get_subset("AdelaideRiver",  "2024_v2", "L3", ["AH", "CO2"])
subset
# Out:
# <xarray.Dataset> Size: 898kB
# Dimensions:     (time: 28070, latitude: 1, longitude: 1)
# Coordinates:
#   * time        (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2009-05-2...
#   * latitude    (latitude) float64 8B -13.08
#   * longitude   (longitude) float64 8B 131.1
# Data variables:
#     AH          (time, latitude, longitude) float64 225kB ...
#     CO2         (time, latitude, longitude) float64 225kB ...
#     AH_QCFlag   (time, latitude, longitude) int32 112kB ...
#     CO2_QCFlag  (time, latitude, longitude) int32 112kB ...
# Attributes: (12/40)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     coverage_flux_L3:         86%
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %%
# Get a subset of 30min dataset from multiple sites, slice to 2 variables
subsets= flux.get_subsets(["AdelaideRiver", "Warra"],  "2024_v2", "L3", ["AH", "CO2"])
subsets
# Out:
# {'AdelaideRiver': <xarray.Dataset> Size: 898kB
#  Dimensions:     (time: 28070, latitude: 1, longitude: 1)
#  Coordinates:
#    * time        (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2009-05-2...
#    * latitude    (latitude) float64 8B -13.08
#    * longitude   (longitude) float64 8B 131.1
#  Data variables:
#      AH          (time, latitude, longitude) float64 225kB ...
#      CO2         (time, latitude, longitude) float64 225kB ...
#      AH_QCFlag   (time, latitude, longitude) int32 112kB ...
#      CO2_QCFlag  (time, latitude, longitude) int32 112kB ...
#  Attributes: (12/40)
#      Conventions:              CF-1.8
#      acknowledgement:          This work used eddy covariance data collected b...
#      canopy_height:            16.4m
#      comment:                  CF metadata, OzFlux standard variable names
#      contact:                  jason.beringer@uwa.edu.au
#      coverage_flux_L3:         86%
#      ...                       ...
#      time_zone:                Australia/Darwin
#      title:                    Flux tower data set from the Adelaide River sit...
#      tower_height:             21m
#      vegetation:               Woody Savanna
#      DODS.strlen:              13
#      DODS.dimName:             name_strlen,
#  'Warra': <xarray.Dataset> Size: 5MB
#  Dimensions:     (time: 149851, latitude: 1, longitude: 1)
#  Coordinates:
#    * time        (time) datetime64[ns] 1MB 2013-03-05T15:00:00 ... 2021-09-21T...
#    * latitude    (latitude) float64 8B -43.1
#    * longitude   (longitude) float64 8B 146.7
#  Data variables:
#      AH          (time, latitude, longitude) float64 1MB ...
#      CO2         (time, latitude, longitude) float64 1MB ...
#      AH_QCFlag   (time, latitude, longitude) int32 599kB ...
#      CO2_QCFlag  (time, latitude, longitude) int32 599kB ...
#  Attributes: (12/41)
#      Conventions:              CF-1.8
#      acknowledgement:          This work used eddy covariance data collected b...
#      altitude:                 108m
#      canopy_height:            55m
#      comment:                  CF metadata, OzFlux standard variable names
#      contact:                  Tim Wardlaw
#      ...                       ...
#      time_zone:                Australia/Hobart
#      title:                    Flux tower data set from the Warra site for the...
#      tower_height:             80
#      vegetation:               Eucalyptus obliqua tall forest
#      DODS.strlen:              5
#      DODS.dimName:             name_strlen}

# %%
# Get a subset of 30min dataset, slice to 2 variables, and temporal range 
subset = flux.get_subset("AdelaideRiver",  "2024_v2", "L3", ["AH", "CO2"], start="2008-01-01 12:30", end="2008-12-31 00:00", keep_qcflags=False)
subset
# Out:
# <xarray.Dataset> Size: 420kB
# Dimensions:    (time: 17496, latitude: 1, longitude: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 140kB 2008-01-01T12:30:00 ... 2008-12-31
#   * latitude   (latitude) float64 8B -13.08
#   * longitude  (longitude) float64 8B 131.1
# Data variables:
#     AH         (time, latitude, longitude) float64 140kB ...
#     CO2        (time, latitude, longitude) float64 140kB ...
# Attributes: (12/40)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     coverage_flux_L3:         86%
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %%
# Save as netcdf file locally
from datetime import datetime
start = datetime.strptime("2008-1-1 12:30", "%Y-%m-%d %H:%M")
end = datetime.strptime("2008-11-30 00:00", "%Y-%m-%d %H:%M")
subset2 = flux.get_subset("AdelaideRiver",  "2024_v2", "L3", ["AH", "CO2"], start, end, missing_as_nan=True)

# save data as netcdf file
subset2.to_netcdf("/Users/uqyliaw/dev/terndata.flux/data/subset2.nf")

# %%
# Get 30-min dataset for a site
flux.get_l6_dataset("AdelaideRiver", "2024_v2", "30min")
# Out:
# <xarray.Dataset> Size: 24MB
# Dimensions:             (time: 28070, latitude: 1, longitude: 1)
# Coordinates:
#   * time                (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2...
#   * latitude            (latitude) float64 8B -13.08
#   * longitude           (longitude) float64 8B 131.1
# Data variables: (12/142)
#     crs                 int32 4B ...
#     station_name        |S64 64B ...
#     AH                  (time, latitude, longitude) float64 225kB ...
#     AH_QCFlag           (time, latitude, longitude) int32 112kB ...
#     AH_HMP_21m          (time, latitude, longitude) float64 225kB ...
#     AH_HMP_21m_QCFlag   (time, latitude, longitude) int32 112kB ...
#     ...                  ...
#     Ws_SONIC_Av         (time, latitude, longitude) float64 225kB ...
#     Ws_SONIC_Av_QCFlag  (time, latitude, longitude) int32 112kB ...
#     ps                  (time, latitude, longitude) float64 225kB ...
#     ps_QCFlag           (time, latitude, longitude) int32 112kB ...
#     ustar               (time, latitude, longitude) float64 225kB ...
#     ustar_QCFlag        (time, latitude, longitude) int32 112kB ...
# Attributes: (12/53)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#     ...                       ...
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna
#     DODS.strlen:              13
#     DODS.dimName:             name_strlen

# %%
# Get daily dataset for a site
flux.get_l6_dataset("AdelaideRiver", "2024_v2", "daily")
# Out:
# <xarray.Dataset> Size: 168kB
# Dimensions:    (time: 584, latitude: 1, longitude: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 5kB 2007-10-18T00:30:00 ... 2009-05-23T0...
#   * latitude   (latitude) float64 8B -13.08
#   * longitude  (longitude) float64 8B 131.1
# Data variables: (12/35)
#     AH         (time, latitude, longitude) float64 5kB ...
#     CO2        (time, latitude, longitude) float64 5kB ...
#     ER         (time, latitude, longitude) float64 5kB ...
#     ER_LL      (time, latitude, longitude) float64 5kB ...
#     ER_LT      (time, latitude, longitude) float64 5kB ...
#     ER_SOLO    (time, latitude, longitude) float64 5kB ...
#     ...         ...
#     Ta         (time, latitude, longitude) float64 5kB ...
#     Ts         (time, latitude, longitude) float64 5kB ...
#     VP         (time, latitude, longitude) float64 5kB ...
#     Ws         (time, latitude, longitude) float64 5kB ...
#     ps         (time, latitude, longitude) float64 5kB ...
#     ustar      (time, latitude, longitude) float64 5kB ...
# Attributes: (12/51)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#     ...                       ...
#     time_coverage_start:      2007-10-17 11:30:00
#     time_step:                daily
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna

# %%
# Get monthly dataset for a site
flux.get_l6_dataset("AdelaideRiver", "2024_v2", "monthly")
# Out:
# <xarray.Dataset> Size: 5kB
# Dimensions:    (time: 19, latitude: 1, longitude: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 152B 2007-11-01T00:30:00 ... 2009-05-01T...
#   * latitude   (latitude) float64 8B -13.08
#   * longitude  (longitude) float64 8B 131.1
# Data variables: (12/35)
#     AH         (time, latitude, longitude) float64 152B ...
#     CO2        (time, latitude, longitude) float64 152B ...
#     ER         (time, latitude, longitude) float64 152B ...
#     ER_LL      (time, latitude, longitude) float64 152B ...
#     ER_LT      (time, latitude, longitude) float64 152B ...
#     ER_SOLO    (time, latitude, longitude) float64 152B ...
#     ...         ...
#     Ta         (time, latitude, longitude) float64 152B ...
#     Ts         (time, latitude, longitude) float64 152B ...
#     VP         (time, latitude, longitude) float64 152B ...
#     Ws         (time, latitude, longitude) float64 152B ...
#     ps         (time, latitude, longitude) float64 152B ...
#     ustar      (time, latitude, longitude) float64 152B ...
# Attributes: (12/51)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#     ...                       ...
#     time_coverage_start:      2007-10-17 11:30:00
#     time_step:                monthly
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna

# %%
# Get annual dataset for a site
flux.get_l6_dataset("AdelaideRiver", "2024_v2", "annual")
# Out:
# <xarray.Dataset> Size: 904B
# Dimensions:    (time: 3, latitude: 1, longitude: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 24B 2007-01-01 2008-01-01 2009-01-01
#   * latitude   (latitude) float64 8B -13.08
#   * longitude  (longitude) float64 8B 131.1
# Data variables: (12/36)
#     AH         (time, latitude, longitude) float64 24B ...
#     CO2        (time, latitude, longitude) float64 24B ...
#     ER         (time, latitude, longitude) float64 24B ...
#     ER_LL      (time, latitude, longitude) float64 24B ...
#     ER_LT      (time, latitude, longitude) float64 24B ...
#     ER_SOLO    (time, latitude, longitude) float64 24B ...
#     ...         ...
#     Ts         (time, latitude, longitude) float64 24B ...
#     VP         (time, latitude, longitude) float64 24B ...
#     Ws         (time, latitude, longitude) float64 24B ...
#     nDays      (time, latitude, longitude) float64 24B ...
#     ps         (time, latitude, longitude) float64 24B ...
#     ustar      (time, latitude, longitude) float64 24B ...
# Attributes: (12/51)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#     ...                       ...
#     time_coverage_start:      2007-10-17 11:30:00
#     time_step:                annual
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna

# %%
# Get cumulative dataset for a site
flux.get_l6_dataset("AdelaideRiver", "2024_v2", "cumulative", missing_as_nan=True)
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:    (time: 28070, latitude: 1, longitude: 1)
# Coordinates:
#   * time       (time) datetime64[ns] 225kB 2007-10-17T11:30:00 ... 2009-05-24...
#   * latitude   (latitude) float64 8B -13.08
#   * longitude  (longitude) float64 8B 131.1
# Data variables: (12/15)
#     ER         (time, latitude, longitude) float64 225kB ...
#     ER_LL      (time, latitude, longitude) float64 225kB ...
#     ER_LT      (time, latitude, longitude) float64 225kB ...
#     ER_SOLO    (time, latitude, longitude) float64 225kB ...
#     ET         (time, latitude, longitude) float64 225kB ...
#     GPP_LL     (time, latitude, longitude) float64 225kB ...
#     ...         ...
#     NEE_LT     (time, latitude, longitude) float64 225kB ...
#     NEE_SOLO   (time, latitude, longitude) float64 225kB ...
#     NEP_LL     (time, latitude, longitude) float64 225kB ...
#     NEP_LT     (time, latitude, longitude) float64 225kB ...
#     NEP_SOLO   (time, latitude, longitude) float64 225kB ...
#     Precip     (time, latitude, longitude) float64 225kB ...
# Attributes: (12/51)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     canopy_height:            16.4m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  jason.beringer@uwa.edu.au
#     controlfile_name:         controlfiles/OzFlux/Tower/L6/AdelaideRiver.txt
#     ...                       ...
#     time_coverage_start:      2007-10-17 11:30:00
#     time_step:                30
#     time_zone:                Australia/Darwin
#     title:                    Flux tower data set from the Adelaide River sit...
#     tower_height:             21m
#     vegetation:               Woody Savanna

# %%
# Get non-existent dataset
flux.get_l6_dataset("CalperumChowilla", "2023_v2", "cumulative")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/.virtualenvs/jupyterlab/lib/python3.13/site-packages/terndata/flux/flux_api.py:289, in get_l6_dataset(site, version, ds_type, missing_as_nan)
#     288 if ds_type not in dataset_urls:
# --> 289     raise Exception(f"Requested '{ds_type}' dataset is not found!")
#     290 return _get_dataset(dataset_urls[ds_type], missing_as_nan)
#
# Exception: Requested 'cumulative' dataset is not found!
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Get non-existent dataset
# ----> 2 flux.get_l6_dataset("CalperumChowilla", "2023_v2", "cumulative")
#
# File ~/.virtualenvs/jupyterlab/lib/python3.13/site-packages/terndata/flux/flux_api.py:292, in get_l6_dataset(site, version, ds_type, missing_as_nan)
#     290     return _get_dataset(dataset_urls[ds_type], missing_as_nan)
#     291 except Exception as e:
# --> 292     raise Exception(
#     293         f"Error: fail to get L6 dataset for site '{site}', version '{version}': {str(e)}"
#     294     ) from e
#
# Exception: Error: fail to get L6 dataset for site 'CalperumChowilla', version '2023_v2': Requested 'cumulative' dataset is not found!

# %%
import os
os.getcwd()
# Out:
# '/Users/uqyliaw/dev/terndata.flux/examples'

# %%
# export 30min dataset as oneflux csv;
flux.export_oneflux_csv("/Users/uqyliaw/dev/terndata.flux/data", "AdelaideRiver", "2024_v2", "L3")
# Out:
# ['/Users/uqyliaw/dev/terndata.flux/data/AU-Adr_qcv_2007.csv',
#  '/Users/uqyliaw/dev/terndata.flux/data/AU-Adr_qcv_2008.csv',
#  '/Users/uqyliaw/dev/terndata.flux/data/AU-Adr_qcv_2009.csv']

# %%
# export 30min dataset as Excel workbook;
flux.export_as_excel("/Users/uqyliaw/dev/terndata.flux/data/Adelaide_L3.xlsx", "AdelaideRiver", "2024_v2", "L3")
# Out:
# '/Users/uqyliaw/dev/terndata.flux/data/Adelaide_L3.xlsx'

# %%
xds = flux.get_dataset("CalperumChowilla", "2024_v2", "L3", missing_as_nan=True)
xds
# Out:
# <xarray.Dataset> Size: 376MB
# Dimensions:              (time: 246194, latitude: 1, longitude: 1)
# Coordinates:
#   * time                 (time) datetime64[ns] 2MB 2010-07-30T11:00:00 ... 20...
#   * latitude             (latitude) float64 8B -34.0
#   * longitude            (longitude) float64 8B 140.6
# Data variables: (12/192)
#     crs                  float64 8B ...
#     station_name         object 8B ...
#     AH                   (time, latitude, longitude) float64 2MB ...
#     AH_QCFlag            (time, latitude, longitude) float64 2MB ...
#     AH_HMP_2m            (time, latitude, longitude) float64 2MB ...
#     AH_HMP_2m_QCFlag     (time, latitude, longitude) float64 2MB ...
#     ...                   ...
#     Ws_SONIC_Av          (time, latitude, longitude) float64 2MB ...
#     Ws_SONIC_Av_QCFlag   (time, latitude, longitude) float64 2MB ...
#     ps                   (time, latitude, longitude) float64 2MB ...
#     ps_QCFlag            (time, latitude, longitude) float64 2MB ...
#     ustar                (time, latitude, longitude) float64 2MB ...
#     ustar_QCFlag         (time, latitude, longitude) float64 2MB ...
# Attributes: (12/44)
#     Conventions:              CF-1.8
#     acknowledgement:          This work used eddy covariance data collected b...
#     altitude:                 60m
#     canopy_height:            3m
#     comment:                  CF metadata, OzFlux standard variable names
#     contact:                  ozfluxtech@adelaide.edu.au
#     ...                       ...
#     time_zone:                Australia/Adelaide
#     title:                    Flux tower data set from the Calperum site for ...
#     tower_height:             20m
#     vegetation:               Mallee
#     DODS.strlen:              8
#     DODS.dimName:             name_strlen

# %%
from terndata.flux import plot

# time-series plot
plot.plot_timeseries(xds, ["Fco2", "Fe", "Fh", "Fm"])

# %%
# Fingureprints plot
plot.plot_fingerprints(xds, ["Fsd", "Fsu", "Fld", "Flu"])
